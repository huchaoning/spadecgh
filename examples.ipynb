# %%
from CGH import *

# %%
# 入射光束的特征宽度, 无需给出波长, 单位为 um
sigma = 103

CGH(sigma, AdvHG(-1), AdvHG(1)).show()
#   ^      ^          ^         ^
# 特征宽度| 模式1   |   模式2   |  方法, show, save 和 result


# show(): 弹出算好的 CGH 的预览, 用 Pillow 实现
# save(file): file 为保存的路径, 同样由 Pillow 实现, 注意要保存成 bmp 格式
# result(): 返回计算好的 CGH 矩阵 (灰度值), 可以做进一步处理

# P.S. 在这里 AdvHG 代指 Zhou2023 文章中的 +- 模式, AdvHG(-1) 表示 - 模式, AdvHG(1) 表示 + 模式
